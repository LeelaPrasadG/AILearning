# %%
import pandas as pd
df = pd.read_csv("/content/sample_data/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = df[['Pclass','Sex','Age','Fare','Survived']]
df
# Out:
#      Pclass     Sex   Age     Fare  Survived
# 0         3    male  22.0   7.2500         0
# 1         1  female  38.0  71.2833         1
# 2         3  female  26.0   7.9250         1
# 3         1  female  35.0  53.1000         1
# 4         3    male  35.0   8.0500         0
# ..      ...     ...   ...      ...       ...
# 886       2    male  27.0  13.0000         0
# 887       1  female  19.0  30.0000         1
# 888       3  female   NaN  23.4500         0
# 889       1    male  26.0  30.0000         1
# 890       3    male  32.0   7.7500         0
#
# [891 rows x 5 columns]

# %%
target_df = df.Survived
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Sex_le'] = le.fit_transform(df.Sex)
preprocessed_df = df.drop(['Survived','Sex'], axis = 'columns')

# %%
preprocessed_df
# Out:
#      Pclass   Age     Fare  Sex_le
# 0         3  22.0   7.2500       1
# 1         1  38.0  71.2833       0
# 2         3  26.0   7.9250       0
# 3         1  35.0  53.1000       0
# 4         3  35.0   8.0500       1
# ..      ...   ...      ...     ...
# 886       2  27.0  13.0000       1
# 887       1  19.0  30.0000       0
# 888       3   NaN  23.4500       0
# 889       1  26.0  30.0000       1
# 890       3  32.0   7.7500       1
#
# [891 rows x 4 columns]

# %%
for feature in preprocessed_df.columns:
  print('Total nulls for the column {} are {}'.format(feature,sum(preprocessed_df[feature].isna())))
# Out:
# Total nulls for the column Pclass are 0
# Total nulls for the column Age are 177
# Total nulls for the column Fare are 0
# Total nulls for the column Sex_le are 0

# %%
preprocessed_df['Age'] = preprocessed_df['Age'].fillna(preprocessed_df.Age.mean())

# %%
preprocessed_df
# Out:
#      Pclass        Age     Fare  Sex_le
# 0         3  22.000000   7.2500       1
# 1         1  38.000000  71.2833       0
# 2         3  26.000000   7.9250       0
# 3         1  35.000000  53.1000       0
# 4         3  35.000000   8.0500       1
# ..      ...        ...      ...     ...
# 886       2  27.000000  13.0000       1
# 887       1  19.000000  30.0000       0
# 888       3  29.699118  23.4500       0
# 889       1  26.000000  30.0000       1
# 890       3  32.000000   7.7500       1
#
# [891 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(preprocessed_df, target_df, test_size=0.2)

# %%
len(X_train)
# Out:
# 712

# %%
len(X_test)
# Out:
# 179

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
model.score(X_test,y_test)
# Out:
# 0.7877094972067039

# %%
y_test[:10]
# Out:
# 642    0
# 638    0
# 238    0
# 575    0
# 44     1
# 344    0
# 202    0
# 261    1
# 177    0
# 779    1
# Name: Survived, dtype: int64

# %%
model.predict(X_test[:10])
# Out:
# array([1, 1, 0, 0, 1, 0, 0, 0, 1, 1])

# %%
model.predict_proba(X_test[:10])
# Out:
# array([[2.42251156e-01, 7.57748844e-01],
#        [3.48822388e-01, 6.51177612e-01],
#        [9.11712146e-01, 8.82878541e-02],
#        [9.55472751e-01, 4.45272487e-02],
#        [3.30821875e-01, 6.69178125e-01],
#        [9.28747120e-01, 7.12528802e-02],
#        [9.62600984e-01, 3.73990159e-02],
#        [9.31241349e-01, 6.87586506e-02],
#        [9.13065787e-02, 9.08693421e-01],
#        [2.30372413e-07, 9.99999770e-01]])
